# %%
from os import walk
from os.path import abspath, join
import os
import pandas as pd

# %%
## All files
base_dir= './gcp_results/updated_labels'

f = []
for (root, dirs, files) in walk(base_dir):
#     f.extend([abspath(d) for d in dirnames])
    path = root.split(os.sep)
    print((len(path) - 1) * '---', os.path.basename(root))
# Out:
# ------ updated_labels
# --------- bert_cnn_arch_size_frozen
# ------------ response_one_split_BERT_cnn_sizes_base_frozen_Jan-27_18-16
# ------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Jan-27_15-36
# ------------ response_one_split_BERT_cnn_sizes_mini_frozen_Jan-27_15-45
# ------------ progression_one_split_BERT_cnn_sizes_tiny_frozen_Mar-03_06-39
# ------------ progression_one_split_BERT_cnn_sizes_base_frozen_Mar-03_06-48
# ------------ response_one_split_BERT_cnn_sizes_med_frozen_Jan-27_16-11
# --------- bert_classifier
# ------------ response_one_split_BERT_sizes_tiny_Feb-10_10-39
# ------------ any_cancer_one_split_BERT_sizes_tiny_Jan-27_14-59
# ------------ response_one_split_BERT_sizes_mini_frozen_Feb-10_14-42
# ------------ any_cancer_one_split_BERT_sizes_tiny_Jan-27_14-48
# ------------ response_one_split_BERT_sizes_med_frozen_Feb-10_15-28
# ------------ response_one_split_BERT_sizes_tiny_frozen_Feb-10_10-16
# ------------ response_one_split_BERT_sizes_base_frozen_Feb-10_19-09
# ------------ response_one_split_BERT_sizes_tiny_frozen_Feb-10_14-27
# ------------ response_one_split_BERT_sizes_mini_Feb-11_08-14
# --------- JAMA
# ------------ response_one_split_sizes_JAMA_Feb-24_11-21
# ------------ progression_one_split_sizes_JAMA_Mar-04_03-09
# ------------ anycancer_one_split_sizes_JAMA_Feb-24_11-32
# --------- clinical_bert
# ------------ progression_one_split_CBERT_cnn_sizes_frozen_Mar-03_20-25
# ------------ response_one_split_CBERT_cnn_sizes_frozen_Feb-24_13-02
# --------- bert_cnn_arch_size
# ------------ any_cancer_one_split_BERT_cnn_sizes_tiny_Jan-27_10-23
# ------------ any_cancer_one_split_BERT_cnn_sizes_tiny_Jan-27_10-24
# ------------ any_cancer_one_split_BERT_cnn_sizes_tiny_Jan-27_10-25
# ------------ any_cancer_one_split_BERT_cnn_sizes_tiny_Jan-27_10-22
# ------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Jan-27_13-13
# ------------ response_one_split_BERT_cnn_sizes_tiny_Jan-27_11-57
# ------------ any_cancer_one_split_BERT_cnn_sizes_tiny_Jan-27_11-18
# ------------ any_cancer_one_split_BERT_cnn_sizes_tiny_frozen_Jan-27_10-20
# ------------ response_one_split_BERT_cnn_sizes_mini_Jan-27_12-13
# --------- tuned_bert_cnn_frozen
# ------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-10_09-31
# ------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-08_15-03
# ------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-10_13-09
# ------------ any_cancer_one_split_BERT_cnn_sizes_tiny_frozen_Feb-10_09-40
# ------------ progression_one_split_BERT_cnn_sizes_tiny_frozen_Mar-03_13-32
# ------------ response_one_split_BERT_cnn_sizes_base_frozen_Feb-24_03-29
# ------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-08_15-22
# ------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-14_15-46
# ------------ progression_one_split_BERT_cnn_sizes_base_frozen_Mar-03_13-41
# ------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-08_15-00
# ------------ any_cancer_one_split_BERT_cnn_sizes_tiny_frozen_Feb-08_15-31
# ------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-10_09-26
# ------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-10_09-29
# --------- longformer
# ------------ response_one_split_BERT_cnn_sizes_long_Mar-06_14-09
# ------------ progression_one_split_BERT_cnn_sizes_long_tuned_Mar-04_05-23
# ------------ response_one_split_BERT_cnn_sizes_long_tuned_Mar-05_09-15
# ------------ progression_one_split_BERT_cnn_sizes_long_Mar-05_23-42
# --------- tfidf
# ------------ response_one_split_tfidf_Feb-24_12-31
# ------------ response_one_split_tfidf_Feb-24_11-56
# ------------ response_one_split_tfidf_Feb-24_11-58
# ------------ response_one_split_tfidf_Feb-24_12-02
# ------------ progression_one_split_tfidf_Mar-04_03-13
# ------------ response_one_split_tfidf_Feb-24_11-55
# ------------ response_one_split_tfidf_Feb-24_11-52

# %%
'''
Task {progression| response}
Model: {BERT| JAMA| TFIDF| clinical BERT| longfromer }
Size: {BASE| TINY| MED|MINI, NA}
Tuned: {TUNED | Original}
Forzen: {forzen| non-forzen|NA}
Classifier : {CNN|RNN|Linear|NA}
'''

#sizes
'bert_cnn_arch_size_frozen'

annotated_files=[]
sub_dir= join(base_dir, 'bert_cnn_arch_size_frozen')

filename= join(sub_dir, 'response_one_split_BERT_cnn_sizes_base_frozen_Jan-27_18-16')
annotated_files.append(dict(Task='response', Model='BERT', Size='base', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))

filename= join(sub_dir, 'response_one_split_BERT_cnn_sizes_tiny_frozen_Jan-27_15-36')
annotated_files.append(dict(Task='response', Model='BERT', Size='tiny', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))


filename= join(sub_dir, 'response_one_split_BERT_cnn_sizes_mini_frozen_Jan-27_15-45')
annotated_files.append(dict(Task='response', Model='BERT', Size='mini', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))


filename= join(sub_dir, 'response_one_split_BERT_cnn_sizes_med_frozen_Jan-27_16-11')
annotated_files.append(dict(Task='response', Model='BERT', Size='med', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))

#progression
filename= join(sub_dir, 'progression_one_split_BERT_cnn_sizes_tiny_frozen_Mar-03_06-39')
annotated_files.append(dict(Task='progression', Model='BERT', Size='tiny', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))


filename= join(sub_dir, 'progression_one_split_BERT_cnn_sizes_base_frozen_Mar-03_06-48')
annotated_files.append(dict(Task='progression', Model='BERT', Size='base', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))

pd.DataFrame(annotated_files)
# Out:
#    Frozen Model  Size         Task  Tuned classifier  \
# 0    True  BERT  base     response  False        CNN
# 1    True  BERT  tiny     response  False        CNN
# 2    True  BERT  mini     response  False        CNN
# 3    True  BERT   med     response  False        CNN
# 4    True  BERT  tiny  progression  False        CNN
# 5    True  BERT  base  progression  False        CNN
#
#                                                 file
# 0  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 1  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 2  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 3  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 4  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 5  ./gcp_results/updated_labels/bert_cnn_arch_siz...

# %%
'''
--------- JAMA
------------ response_one_split_sizes_JAMA_Feb-24_11-21
------------ progression_one_split_sizes_JAMA_Mar-04_03-09
------------ anycancer_one_split_sizes_JAMA_Feb-24_11-32
'''

sub_dir= join(base_dir, 'JAMA')
filename= join(sub_dir, 'response_one_split_sizes_JAMA_Feb-24_11-21')
annotated_files.append(dict(Task='response', Model='CNN', Size='NA', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))

filename= join(sub_dir, 'progression_one_split_sizes_JAMA_Mar-04_03-09')
annotated_files.append(dict(Task='progression', Model='CNN', Size='NA', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))

pd.DataFrame(annotated_files)
# Out:
#    Frozen Model  Size         Task  Tuned classifier  \
# 0    True  BERT  base     response  False        CNN
# 1    True  BERT  tiny     response  False        CNN
# 2    True  BERT  mini     response  False        CNN
# 3    True  BERT   med     response  False        CNN
# 4    True  BERT  tiny  progression  False        CNN
# 5    True  BERT  base  progression  False        CNN
# 6    True   CNN    NA     response  False        CNN
# 7    True   CNN    NA  progression  False        CNN
#
#                                                 file
# 0  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 1  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 2  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 3  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 4  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 5  ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 6  ./gcp_results/updated_labels/JAMA/response_one...
# 7  ./gcp_results/updated_labels/JAMA/progression_...

# %%
'''
--------- longformer
------------ response_one_split_BERT_cnn_sizes_long_Mar-06_14-09
------------ progression_one_split_BERT_cnn_sizes_long_tuned_Mar-04_05-23
------------ response_one_split_BERT_cnn_sizes_long_tuned_Mar-05_09-15
------------ progression_one_split_BERT_cnn_sizes_long_Mar-05_23-42
'''

sub_dir= join(base_dir, 'longformer')
filename= join(sub_dir, 'response_one_split_BERT_cnn_sizes_long_Mar-06_14-09')
annotated_files.append(dict(Task='response', Model='longformer', Size='base', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))


filename= join(sub_dir, 'progression_one_split_BERT_cnn_sizes_long_Mar-05_23-42')
annotated_files.append(dict(Task='progression', Model='longformer', Size='base', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))


filename= join(sub_dir, 'response_one_split_BERT_cnn_sizes_long_tuned_Mar-05_09-15')
annotated_files.append(dict(Task='response', Model='longformer', Size='base', Tuned= True, Frozen=True,classifier = 'CNN', file=filename))


filename= join(sub_dir, 'progression_one_split_BERT_cnn_sizes_long_tuned_Mar-04_05-23')
annotated_files.append(dict(Task='progression', Model='longformer', Size='base', Tuned= True, Frozen=True,classifier = 'CNN', file=filename))

pd.DataFrame(annotated_files)
# Out:
#     Frozen       Model  Size         Task  Tuned classifier  \
# 0     True        BERT  base     response  False        CNN
# 1     True        BERT  tiny     response  False        CNN
# 2     True        BERT  mini     response  False        CNN
# 3     True        BERT   med     response  False        CNN
# 4     True        BERT  tiny  progression  False        CNN
# 5     True        BERT  base  progression  False        CNN
# 6     True         CNN    NA     response  False        CNN
# 7     True         CNN    NA  progression  False        CNN
# 8     True  longformer  base     response  False        CNN
# 9     True  longformer  base  progression  False        CNN
# 10    True  longformer  base     response   True        CNN
# 11    True  longformer  base  progression   True        CNN
#
#                                                  file
# 0   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 1   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 2   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 3   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 4   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 5   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 6   ./gcp_results/updated_labels/JAMA/response_one...
# 7   ./gcp_results/updated_labels/JAMA/progression_...
# 8   ./gcp_results/updated_labels/longformer/respon...
# 9   ./gcp_results/updated_labels/longformer/progre...
# 10  ./gcp_results/updated_labels/longformer/respon...
# 11  ./gcp_results/updated_labels/longformer/progre...

# %%
'''
--------- tuned_bert_cnn_frozen
------------ progression_one_split_BERT_cnn_sizes_tiny_frozen_Mar-03_13-32
------------ progression_one_split_BERT_cnn_sizes_base_frozen_Mar-03_13-41
------------ response_one_split_BERT_cnn_sizes_base_frozen_Feb-24_03-29
------------ response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-14_15-46
'''

sub_dir= join(base_dir, 'tuned_bert_cnn_frozen')
filename= join(sub_dir, 'response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-14_15-46')
annotated_files.append(dict(Task='response', Model='BERT', Size='tiny', Tuned= True, Frozen=True,classifier = 'CNN', file=filename))

filename= join(sub_dir, 'response_one_split_BERT_cnn_sizes_base_frozen_Feb-24_03-29')
annotated_files.append(dict(Task='response', Model='BERT', Size='base', Tuned= True, Frozen=True,classifier = 'CNN', file=filename))



filename= join(sub_dir, 'progression_one_split_BERT_cnn_sizes_base_frozen_Mar-03_13-41')
annotated_files.append(dict(Task='progression', Model='BERT', Size='base', Tuned= True, Frozen=True,classifier = 'CNN', file=filename))

filename= join(sub_dir, 'progression_one_split_BERT_cnn_sizes_tiny_frozen_Mar-03_13-32')
annotated_files.append(dict(Task='progression', Model='BERT', Size='tiny', Tuned= True, Frozen=True,classifier = 'CNN', file=filename))

pd.DataFrame(annotated_files)
# Out:
#     Frozen       Model  Size         Task  Tuned classifier  \
# 0     True        BERT  base     response  False        CNN
# 1     True        BERT  tiny     response  False        CNN
# 2     True        BERT  mini     response  False        CNN
# 3     True        BERT   med     response  False        CNN
# 4     True        BERT  tiny  progression  False        CNN
# 5     True        BERT  base  progression  False        CNN
# 6     True         CNN    NA     response  False        CNN
# 7     True         CNN    NA  progression  False        CNN
# 8     True  longformer  base     response  False        CNN
# 9     True  longformer  base  progression  False        CNN
# 10    True  longformer  base     response   True        CNN
# 11    True  longformer  base  progression   True        CNN
# 12    True        BERT  tiny     response   True        CNN
# 13    True        BERT  base     response   True        CNN
# 14    True        BERT  base  progression   True        CNN
# 15    True        BERT  tiny  progression   True        CNN
#
#                                                  file
# 0   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 1   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 2   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 3   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 4   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 5   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 6   ./gcp_results/updated_labels/JAMA/response_one...
# 7   ./gcp_results/updated_labels/JAMA/progression_...
# 8   ./gcp_results/updated_labels/longformer/respon...
# 9   ./gcp_results/updated_labels/longformer/progre...
# 10  ./gcp_results/updated_labels/longformer/respon...
# 11  ./gcp_results/updated_labels/longformer/progre...
# 12  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 13  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 14  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 15  ./gcp_results/updated_labels/tuned_bert_cnn_fr...

# %%
'''
--------- tfidf
------------ response_one_split_tfidf_Feb-24_12-31
------------ progression_one_split_tfidf_Mar-04_03-13

'''
sub_dir= join(base_dir, 'tfidf')
filename= join(sub_dir, 'response_one_split_tfidf_Feb-24_12-31')
annotated_files.append(dict(Task='response', Model='tfidf', Size='NA', Tuned= True, Frozen=True,classifier = 'CNN', file=filename))


filename= join(sub_dir, 'progression_one_split_tfidf_Mar-04_03-13')
annotated_files.append(dict(Task='progression', Model='tfidf', Size='NA', Tuned= True, Frozen=True,classifier = 'CNN', file=filename))

pd.DataFrame(annotated_files)
# Out:
#     Frozen       Model  Size         Task  Tuned classifier  \
# 0     True        BERT  base     response  False        CNN
# 1     True        BERT  tiny     response  False        CNN
# 2     True        BERT  mini     response  False        CNN
# 3     True        BERT   med     response  False        CNN
# 4     True        BERT  tiny  progression  False        CNN
# 5     True        BERT  base  progression  False        CNN
# 6     True         CNN    NA     response  False        CNN
# 7     True         CNN    NA  progression  False        CNN
# 8     True  longformer  base     response  False        CNN
# 9     True  longformer  base  progression  False        CNN
# 10    True  longformer  base     response   True        CNN
# 11    True  longformer  base  progression   True        CNN
# 12    True        BERT  tiny     response   True        CNN
# 13    True        BERT  base     response   True        CNN
# 14    True        BERT  base  progression   True        CNN
# 15    True        BERT  tiny  progression   True        CNN
# 16    True       tfidf    NA     response   True        CNN
# 17    True       tfidf    NA  progression   True        CNN
#
#                                                  file
# 0   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 1   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 2   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 3   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 4   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 5   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 6   ./gcp_results/updated_labels/JAMA/response_one...
# 7   ./gcp_results/updated_labels/JAMA/progression_...
# 8   ./gcp_results/updated_labels/longformer/respon...
# 9   ./gcp_results/updated_labels/longformer/progre...
# 10  ./gcp_results/updated_labels/longformer/respon...
# 11  ./gcp_results/updated_labels/longformer/progre...
# 12  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 13  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 14  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 15  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 16  ./gcp_results/updated_labels/tfidf/response_on...
# 17  ./gcp_results/updated_labels/tfidf/progression...

# %%
'''
--------- clinical_bert
------------ progression_one_split_CBERT_cnn_sizes_frozen_Mar-03_20-25
------------ response_one_split_CBERT_cnn_sizes_frozen_Feb-24_13-02
'''

sub_dir= join(base_dir, 'clinical_bert')
filename= join(sub_dir, 'response_one_split_CBERT_cnn_sizes_frozen_Feb-24_13-02')
annotated_files.append(dict(Task='response', Model='clinical BERT', Size='base', Tuned= False, Frozen=True, classifier = 'CNN', file=filename))


filename= join(sub_dir, 'progression_one_split_CBERT_cnn_sizes_frozen_Mar-03_20-25')
annotated_files.append(dict(Task='progression', Model='clinical BERT', Size='base', Tuned= False, Frozen=True, classifier = 'CNN', file=filename))


pd.DataFrame(annotated_files)
# Out:
#     Frozen          Model  Size         Task  Tuned classifier  \
# 0     True           BERT  base     response  False        CNN
# 1     True           BERT  tiny     response  False        CNN
# 2     True           BERT  mini     response  False        CNN
# 3     True           BERT   med     response  False        CNN
# 4     True           BERT  tiny  progression  False        CNN
# 5     True           BERT  base  progression  False        CNN
# 6     True            CNN    NA     response  False        CNN
# 7     True            CNN    NA  progression  False        CNN
# 8     True     longformer  base     response  False        CNN
# 9     True     longformer  base  progression  False        CNN
# 10    True     longformer  base     response   True        CNN
# 11    True     longformer  base  progression   True        CNN
# 12    True           BERT  tiny     response   True        CNN
# 13    True           BERT  base     response   True        CNN
# 14    True           BERT  base  progression   True        CNN
# 15    True           BERT  tiny  progression   True        CNN
# 16    True          tfidf    NA     response   True        CNN
# 17    True          tfidf    NA  progression   True        CNN
# 18    True  clinical BERT  base     response  False        CNN
# 19    True  clinical BERT  base  progression  False        CNN
#
#                                                  file
# 0   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 1   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 2   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 3   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 4   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 5   ./gcp_results/updated_labels/bert_cnn_arch_siz...
# 6   ./gcp_results/updated_labels/JAMA/response_one...
# 7   ./gcp_results/updated_labels/JAMA/progression_...
# 8   ./gcp_results/updated_labels/longformer/respon...
# 9   ./gcp_results/updated_labels/longformer/progre...
# 10  ./gcp_results/updated_labels/longformer/respon...
# 11  ./gcp_results/updated_labels/longformer/progre...
# 12  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 13  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 14  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 15  ./gcp_results/updated_labels/tuned_bert_cnn_fr...
# 16  ./gcp_results/updated_labels/tfidf/response_on...
# 17  ./gcp_results/updated_labels/tfidf/progression...
# 18  ./gcp_results/updated_labels/clinical_bert/res...
# 19  ./gcp_results/updated_labels/clinical_bert/pro...

# %%
'''
--------- bert_classifier
------------ response_one_split_BERT_sizes_tiny_Feb-10_10-39
------------ any_cancer_one_split_BERT_sizes_tiny_Jan-27_14-59
------------ response_one_split_BERT_sizes_mini_frozen_Feb-10_14-42
------------ any_cancer_one_split_BERT_sizes_tiny_Jan-27_14-48
------------ response_one_split_BERT_sizes_med_frozen_Feb-10_15-28
------------ response_one_split_BERT_sizes_tiny_frozen_Feb-10_10-16
------------ response_one_split_BERT_sizes_base_frozen_Feb-10_19-09
------------ response_one_split_BERT_sizes_tiny_frozen_Feb-10_14-27
------------ response_one_split_BERT_sizes_mini_Feb-11_08-14
'''

sub_dir= join(base_dir, 'bert_classifier')
filename= join(sub_dir, 'response_one_split_BERT_sizes_tiny_Feb-10_10-39')
annotated_files.append(dict(Task='response', Model='BERT', Size='tiny', Tuned= False, Frozen=True,classifier = 'CNN', file=filename))
# Out:
# ['/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/bert_cnn_arch_size_frozen',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/bert_classifier',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/JAMA',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/clinical_bert',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/bert_cnn_arch_size',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/tuned_bert_cnn_frozen',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/longformer',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/tfidf',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_base_frozen_Jan-27_18-16',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_frozen_Jan-27_15-36',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_mini_frozen_Jan-27_15-45',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/progression_one_split_BERT_cnn_sizes_tiny_frozen_Mar-03_06-39',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/progression_one_split_BERT_cnn_sizes_base_frozen_Mar-03_06-48',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_med_frozen_Jan-27_16-11',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_sizes_tiny_Feb-10_10-39',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/any_cancer_one_split_BERT_sizes_tiny_Jan-27_14-59',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_sizes_mini_frozen_Feb-10_14-42',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/any_cancer_one_split_BERT_sizes_tiny_Jan-27_14-48',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_sizes_med_frozen_Feb-10_15-28',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_sizes_tiny_frozen_Feb-10_10-16',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_sizes_base_frozen_Feb-10_19-09',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_sizes_tiny_frozen_Feb-10_14-27',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_sizes_mini_Feb-11_08-14',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_sizes_JAMA_Feb-24_11-21',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/progression_one_split_sizes_JAMA_Mar-04_03-09',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/anycancer_one_split_sizes_JAMA_Feb-24_11-32',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/progression_one_split_CBERT_cnn_sizes_frozen_Mar-03_20-25',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_CBERT_cnn_sizes_frozen_Feb-24_13-02',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/any_cancer_one_split_BERT_cnn_sizes_tiny_Jan-27_10-23',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/any_cancer_one_split_BERT_cnn_sizes_tiny_Jan-27_10-24',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/any_cancer_one_split_BERT_cnn_sizes_tiny_Jan-27_10-25',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/any_cancer_one_split_BERT_cnn_sizes_tiny_Jan-27_10-22',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_frozen_Jan-27_13-13',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_Jan-27_11-57',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/any_cancer_one_split_BERT_cnn_sizes_tiny_Jan-27_11-18',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/any_cancer_one_split_BERT_cnn_sizes_tiny_frozen_Jan-27_10-20',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_mini_Jan-27_12-13',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-10_09-31',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-08_15-03',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-10_13-09',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/any_cancer_one_split_BERT_cnn_sizes_tiny_frozen_Feb-10_09-40',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/progression_one_split_BERT_cnn_sizes_tiny_frozen_Mar-03_13-32',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_base_frozen_Feb-24_03-29',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-08_15-22',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-14_15-46',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/progression_one_split_BERT_cnn_sizes_base_frozen_Mar-03_13-41',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-08_15-00',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/any_cancer_one_split_BERT_cnn_sizes_tiny_frozen_Feb-08_15-31',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-10_09-26',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_tiny_frozen_Feb-10_09-29',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_long_Mar-06_14-09',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/progression_one_split_BERT_cnn_sizes_long_tuned_Mar-04_05-23',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_BERT_cnn_sizes_long_tuned_Mar-05_09-15',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/progression_one_split_BERT_cnn_sizes_long_Mar-05_23-42',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_tfidf_Feb-24_12-31',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_tfidf_Feb-24_11-56',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_tfidf_Feb-24_11-58',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_tfidf_Feb-24_12-02',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/progression_one_split_tfidf_Mar-04_03-13',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_tfidf_Feb-24_11-55',
#  '/Users/haithamelmarakeby/PycharmProjects/clinicalNLP2/analysis/response_one_split_tfidf_Feb-24_11-52']
